# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# !pip install -r requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15926, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 15926 (delta 20), reused 23 (delta 8), pack-reused 15880
# Receiving objects: 100% (15926/15926), 14.66 MiB | 7.11 MiB/s, done.
# Resolving deltas: 100% (10915/10915), done.
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 610.8/610.8 kB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.9 MB/s eta 0:00:00
# ...

# %%
# !mkdir -p "/content/yolov5/80000file/images"

# %%
# !unzip "/content/drive/MyDrive/공사현장 인식 프로젝트/output_image1.zip" -d "/content/yolov5/80000file/images"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/yolov5/80000file/images/S2-N2103M37134.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37136.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37139.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37141.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37142.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37143.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37144.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37148.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37152.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37160.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37163.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37164.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37168.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37169.jpg
# ...

# %%
# !unzip "/content/drive/MyDrive/공사현장 인식 프로젝트/output_image2.zip" -d "/content/yolov5/80000file/images"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/yolov5/80000file/images/S2-N2103M36815.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36820.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36831.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36834.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36835.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36840.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36847.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36849.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36859.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36862.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36866.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36869.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36873.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M36880.jpg
# ...

# %%
# !unzip "/content/drive/MyDrive/공사현장 인식 프로젝트/output_image3.zip" -d "/content/yolov5/80000file/images"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/yolov5/80000file/images/S2-N2103M37327.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37334.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37335.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37340.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37351.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37357.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37365.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37370.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37371.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37372.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37378.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37381.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37383.jpg
#   inflating: /content/yolov5/80000file/images/S2-N2103M37385.jpg
# ...

# %%
# !unzip "/content/drive/MyDrive/공사현장 인식 프로젝트/labels.zip" -d "/content/yolov5/80000file"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49032.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49033.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49034.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49035.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49036.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49037.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49038.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49039.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49041.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49042.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49043.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49044.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49045.txt
#   inflating: /content/yolov5/80000file/labels/S2-N2103M49046.txt
# ...

# %%
import os

# %%
len(os.listdir("/content/yolov5/80000file/images"))
# Out:
# 87554

# %%
len(os.listdir("/content/yolov5/80000file/labels"))
# Out:
# 87554

# %%
yaml_content = """
train: /content/yolov5/80000file
val: /content/yolov5/80000file

nc: 4
names: ['off_harness', 'on_harness', 'off_helmet', 'on_helmet']
"""

with open('/content/yolov5/data/custom.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !python train.py  --weights "/content/drive/MyDrive/공사현장 인식 프로젝트/best_6900.pt" --data "/content/yolov5/data/custom.yaml" --epochs 3
# Out:
# train: weights=/content/drive/MyDrive/공사현장 인식 프로젝트/best_6900.pt, cfg=, data=/content/yolov5/data/custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !zip -r train_result_epoch3.zip /content/yolov5/runs/train/exp
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/train_batch2.jpg (deflated 5%)
#   adding: content/yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 5%)
#   adding: content/yolov5/runs/train/exp/P_curve.png (deflated 12%)
#   adding: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/exp/train_batch1.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/exp/confusion_matrix.png (deflated 26%)
#   adding: content/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/best.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/weights/last.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/val_batch2_labels.jpg (deflated 5%)
#   adding: content/yolov5/runs/train/exp/labels.jpg (deflated 31%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 50%)
# ...

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/best.pt" --source "/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4"

# 탐지하는 부분이에요! 앞에는 best.pt값 집어넣으시고, 뒤에는 해당 비디오 파일 집어넣으시면 yolo가 탐지합니다!
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/281) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4: 640x384 1 off_harness, 1 on_helmet, 74.2ms
# video 1/1 (2/281) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4: 640x384 1 off_harness, 2 on_helmets, 10.0ms
# ...
